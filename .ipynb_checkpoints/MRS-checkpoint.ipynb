# %%
import pandas as pd
import numpy as np
import time

# %%
ratings = pd.read_csv("./ml-latest-small/ratings.csv")
ratings[ratings.userId==1].head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
movies = pd.read_csv('./ml-latest/movies.csv', encoding='latin-1')
print (movies.shape)
movies.head()
# Out:
# (58098, 3)
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
num_users = ratings.userId.unique().shape[0]
num_items = ratings.movieId.unique().shape[0]
num_users, num_items
# Out:
# (610, 9724)

# %%
from sklearn import model_selection as ms
train_set, test_set = ms.train_test_split(ratings, test_size=0.25)
len(train_set), len(test_set)
# Out:
# (75627, 25209)

# %%
user_movie_matrix = ratings.pivot(index='userId', columns='movieId', values='rating')
print("UM Matrix value size", user_movie_matrix.values.size)
print("ratings value size", ratings.values.size)
print("Sparisity: {:4.2f}%".format(ratings.rating.values.size/user_movie_matrix.values.size*100))
user_movie_matrix.head(10)
# Out:
# UM Matrix value size 5931640
# ratings value size 403344
# Sparisity: 1.70%
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6           NaN     4.0     5.0     3.0     5.0     4.0     4.0     3.0
# 7           4.5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8           NaN     4.0     NaN     NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10       ...    193565  193567  193571  193573  193579  \
# userId                    ...
# 1           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 6           NaN     3.0   ...       NaN     NaN     NaN     NaN     NaN
# 7           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 8           NaN     2.0   ...       NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
#
# movieId  193581  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN
# 6           NaN     NaN     NaN     NaN     NaN
# 7           NaN     NaN     NaN     NaN     NaN
# 8           NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN     NaN     NaN     NaN
#
# [10 rows x 9724 columns]

# %%
# similarity
import math
from operator import itemgetter
from scipy.spatial import distance

def distance_cosine(a,b):
    return 1-distance.cosine(a,b)

def disance_corr(a,b):
    return 1-distance.correlation(a,b)

def distance_euclidean(a,b):
    return 1/(distance.euclidean(a,b)+1)

# %%
def nearest_neighbor_user(user, topN, simFunc) :  
    u1 = user_movie_matrix.loc[user].dropna()
    ratedIndex = u1.index
    nn = {}
    
    # Brute-Force Compute
    for uid, row in user_movie_matrix.iterrows():
        interSectionU1 = []
        interSectionU2 = []
        if uid==user:
            continue
            
        for i in ratedIndex:
            if False==math.isnan(row[i]):
                interSectionU1.append(u1[i])
                interSectionU2.append(row[i])
        interSectionLen = len(interSectionU1)
        
        # at least 3 intersection items
        if interSectionLen < 3 :
            continue
            
        # similarity functon
        sim = simFunc(interSectionU1, interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[uid] = sim
            
    # top N returned         
    return sorted(nn.items(),key=itemgetter(1),reverse=True)[:(topN+1)]

# %%
def nearest_neighbor_item(movie, topN, simFunc):
    m1 = user_movie_matrix[movie].dropna()
    user_index = m1.index
    nn = {}
    
    for movieId, col in user_movie_matrix.iteritems():
        interSectionU1 = []
        interSectionU2 = []
        if movie == movieId:
            continue
        
        for i in user_index:
            if False==math.isnan(col[i]):
                interSectionU1.append(m1[i])
                interSectionU2.append(col[i])
        interSectionLen = len(interSectionU1)
        
        # at least 3 intersection items
        if interSectionLen < 3:
            continue
            
        # similarity functon
        sim = simFunc(interSectionU1, interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[movieId] = sim
            
    # top N returned         
    return sorted(nn.items(),key=itemgetter(1),reverse=True)[:(topN+1)]

# %%
print(pd.DataFrame(nearest_neighbor_user(278, 100, distance_euclidean), columns=['userId', 'sim']).head())
print(pd.DataFrame(nearest_neighbor_item(1, 100, distance_euclidean), columns=['movieId', 'sim']).head())
# Out:
#    userId  sim
# 0       8  1.0
# 1      15  1.0
# 2     348  1.0
# 3     352  1.0
# 4     373  1.0
#    movieId  sim
# 0     1484  1.0
# 1     2932  1.0
# 2     2940  1.0
# 3     2967  1.0
# 4     2988  1.0

# %%
def predictRating(id_num, nn=50, simFunc=distance_euclidean, kind = 'user') :
   
    if (kind == "user"):
        ## neighboorhood 
        neighbor = nearest_neighbor_user(id_num, nn, simFunc)

        neighbor_id = [id for id, sim in neighbor]
        # List of similar similarities

        ## Remove if two or more are NaN
        neighbor_movie = user_movie_matrix.loc[neighbor_id].dropna(1, how = 'all', thresh = 2)
        # User id x DataFrame of movie id. However, if the NaN of the column is 2 or more, it is deleted.

        neighbor_dic = dict(neighbor)
        ret = [] 
        #['movieId', 'predictedRate']

        # iterate through each column key: userid, column: movieid, value: rating
        for movieId, row in neighbor_movie.iteritems():
            jsum, wsum = 0, 0
            for v in row.dropna().iteritems():
                sim = neighbor_dic.get(v[0],0)
                jsum += sim
                wsum += (v[1]*sim)
            ret.append([movieId, wsum/jsum])

        return ret
    
    elif (kind == 'item'):
        neighbor = nearest_neighbor_item(id_num, nn, simFunc)
        
        neighbor_id = [id for id, sim in neighbor]
        
        neighbor_ratedUser = user_movie_matrix[neighbor_id].dropna(0, how = 'all', thresh = 2)
        
        neighbor_dic = dict(neighbor)
        ret = []
        
        for userId, row in neighbor_ratedUser.iterrows():
            jsum, wsum = 0, 0
            for v in row.dropna().iteritems():
                sim = neighbor_dic.get(v[0], 0)
                jsum += sim
                wsum += (v[1]*sim)
            ret.append([userId, wsum/jsum])
        
        return ret

# %%
# predictRating(1, 100, kind = 'user')
predictRating(1, 50, kind = 'item')
# Out:
# [[50, 3.333333333333333],
#  [51, 4.25],
#  [66, 4.0],
#  [103, 4.25],
#  [105, 4.333333333333333],
#  [125, 4.0],
#  [140, 3.1169278186182687],
#  [182, 4.096214921515367],
#  [186, 4.0],
#  [199, 3.5],
#  [202, 4.0],
#  [221, 3.652618519826359],
#  [249, 4.4],
#  [260, 4.467711274473075],
#  [274, 3.815300968740935],
#  [275, 5.0],
#  [290, 4.0],
#  [313, 4.0],
#  [318, 3.1249999999999996],
#  [325, 4.0],
#  [368, 3.0],
#  [377, 3.75],
#  [380, 4.999999999999999],
#  [387, 3.5739934013937824],
#  [414, 3.980591134835224],
#  [422, 4.0],
#  [469, 4.0],
#  [474, 3.7895693619823407],
#  [479, 4.2],
#  [483, 3.9677112744730745],
#  [489, 3.766144362763463],
#  [509, 4.0],
#  [514, 4.0],
#  [534, 4.0],
#  [555, 4.0],
#  [590, 4.0],
#  [597, 4.0],
#  [599, 2.8977036061322035],
#  [600, 2.4677112744730745],
#  [603, 4.0],
#  [606, 2.6348760716949085]]

# %%
## view rated movies and movies with high ratings
def ratingMovies(user_id):
    ds = pd.merge(ratings[ratings.userId==user_id], movies, on=['movieId'])
    return ds.sort_values(by=['rating'], ascending=False)[['rating','title','genres','movieId']].head(100)
ratingMovies(1).head()
# Out:
#      rating                                      title  \
# 231     5.0               M*A*S*H (a.k.a. MASH) (1970)
# 185     5.0                           Excalibur (1981)
# 89      5.0  Indiana Jones and the Last Crusade (1989)
# 90      5.0                Pink Floyd: The Wall (1982)
# 190     5.0               From Russia with Love (1963)
#
#                         genres  movieId
# 231           Comedy|Drama|War     5060
# 185          Adventure|Fantasy     2872
# 89            Action|Adventure     1291
# 90               Drama|Musical     1298
# 190  Action|Adventure|Thriller     2948

# %%
def join_movie_info(predicted_result, movie = 1, kind = 'user'):
    if (kind == 'user'):
        predicted_ratings = pd.DataFrame(predicted_result, columns=['movieId', 'predicted_rating'])
        result_ds = pd.merge(movies[movies.movieId > 0], predicted_ratings, on=['movieId'])
        return result_ds.sort_values(by=['predicted_rating'], ascending=False)
    
    elif (kind == 'item'):
        predicted_ratings = pd.DataFrame(predicted_result, columns=['userId', 'predicted_rating'])
        return predicted_ratings.sort_values(by=['predicted_rating'], ascending=False)
    
result_user = predictRating(50, kind = 'user') # prediction of user #50
result_item = predictRating(1, kind = 'item') # prediction of movie #1
join_movie_info(result_user, kind = 'user').head(10)
# Out:
#      movieId                                          title  \
# 35        76                               Screamers (1995)
# 288     3499                                  Misery (1990)
# 236     1221                 Godfather: Part II, The (1974)
# 233     1213                              Goodfellas (1990)
# 247     1358                             Sling Blade (1996)
# 147      541                            Blade Runner (1982)
# 298     5952  Lord of the Rings: The Two Towers, The (2002)
# 221     1089                          Reservoir Dogs (1992)
# 262     1961                                Rain Man (1988)
# 255     1673                           Boogie Nights (1997)
#
#                      genres  predicted_rating
# 35   Action|Sci-Fi|Thriller          5.000000
# 288   Drama|Horror|Thriller          4.795540
# 236             Crime|Drama          4.768673
# 233             Crime|Drama          4.712773
# 247                   Drama          4.543199
# 147  Action|Sci-Fi|Thriller          4.542570
# 298       Adventure|Fantasy          4.540473
# 221  Crime|Mystery|Thriller          4.516075
# 262                   Drama          4.514331
# 255                   Drama          4.512385

# %%
join_movie_info(result_item, kind = 'item').head(10)
# Out:
#     userId  predicted_rating
# 15     275          5.000000
# 22     380          5.000000
# 13     260          4.467711
# 12     249          4.400000
# 4      105          4.333333
# 1       51          4.250000
# 3      103          4.250000
# 28     479          4.200000
# 7      182          4.096215
# 36     597          4.000000

# %%
# 5th user's star rating
userId=1
pd.merge(ratingMovies(userId), join_movie_info(predictRating(userId)), 
         on=['movieId'], how='right').sort_values(by=['predicted_rating'], ascending =False)
# Out:
#      rating                                            title_x  \
# 25      NaN                                                NaN
# 35      NaN                                                NaN
# 34      NaN                                                NaN
# 1       5.0                           L.A. Confidential (1997)
# 33      NaN                                                NaN
# 7       5.0                         Princess Bride, The (1987)
# 32      NaN                                                NaN
# 31      NaN                                                NaN
# 30      NaN                                                NaN
# 29      NaN                                                NaN
# 28      NaN                                                NaN
# 27      NaN                                                NaN
# 26      NaN                                                NaN
# 15      5.0                                       Fargo (1996)
# 0       5.0                             American Beauty (1999)
# 36      NaN                                                NaN
# 37      NaN                                                NaN
# 12      5.0  Raiders of the Lost Ark (Indiana Jones and the...
# 38      NaN                                                NaN
# 39      NaN                                                NaN
# 40      NaN                                                NaN
# 41      NaN                                                NaN
# 19      5.0                                   Gladiator (2000)
# 6       5.0  Star Wars: Episode VI - Return of the Jedi (1983)
# 14      5.0  Star Wars: Episode V - The Empire Strikes Back...
# 42      NaN                                                NaN
# 43      NaN                                                NaN
# 44      NaN                                                NaN
# 24      5.0                        Seven (a.k.a. Se7en) (1995)
# 45      NaN                                                NaN
# ..      ...                                                ...
# 317     NaN                                                NaN
# 318     NaN                                                NaN
# 319     NaN                                                NaN
# 320     NaN                                                NaN
# 321     NaN                                                NaN
# 322     NaN                                                NaN
# 323     NaN                                                NaN
# 324     NaN                                                NaN
# 325     NaN                                                NaN
# 326     NaN                                                NaN
# 327     NaN                                                NaN
# 328     NaN                                                NaN
# 329     NaN                                                NaN
# 330     NaN                                                NaN
# 331     NaN                                                NaN
# 332     NaN                                                NaN
# 333     NaN                                                NaN
# 334     NaN                                                NaN
# 335     NaN                                                NaN
# 336     NaN                                                NaN
# 337     NaN                                                NaN
# 338     NaN                                                NaN
# 339     NaN                                                NaN
# 340     NaN                                                NaN
# 341     NaN                                                NaN
# 342     NaN                                                NaN
# 343     NaN                                                NaN
# 344     NaN                                                NaN
# 345     NaN                                                NaN
# 346     NaN                                                NaN
#
#                                     genres_x  movieId  \
# 25                                       NaN     3996
# 35                                       NaN     1982
# 34                                       NaN     6502
# 1           Crime|Film-Noir|Mystery|Thriller     1617
# 33                                       NaN     1203
# 7    Action|Adventure|Comedy|Fantasy|Romance     1197
# 32                                       NaN      923
# 31                                       NaN      381
# 30                                       NaN   177593
# 29                                       NaN       25
# 28                                       NaN       17
# 27                                       NaN      588
# 26                                       NaN     2396
# 15               Comedy|Crime|Drama|Thriller      608
# 0                              Drama|Romance     2858
# 36                                       NaN     4896
# 37                                       NaN     5971
# 12                          Action|Adventure     1198
# 38                                       NaN     1221
# 39                                       NaN     5902
# 40                                       NaN     3147
# 41                                       NaN   168252
# 19                    Action|Adventure|Drama     3578
# 6                    Action|Adventure|Sci-Fi     1210
# 14                   Action|Adventure|Sci-Fi     1196
# 42                                       NaN    66934
# 43                                       NaN       62
# 44                                       NaN     5618
# 24                          Mystery|Thriller       47
# 45                                       NaN     6711
# ..                                       ...      ...
# 317                                      NaN     1407
# 318                                      NaN      468
# 319                                      NaN      350
# 320                                      NaN       81
# 321                                      NaN      371
# 322                                      NaN    85414
# 323                                      NaN      104
# 324                                      NaN    73321
# 325                                      NaN      380
# 326                                      NaN     1414
# 327                                      NaN     1639
# 328                                      NaN     2770
# 329                                      NaN   175569
# 330                                      NaN     2100
# 331                                      NaN     7438
# 332                                      NaN       31
# 333                                      NaN   122886
# 334                                      NaN   187541
# 335                                      NaN     2968
# 336                                      NaN    97921
# 337                                      NaN      743
# 338                                      NaN      185
# 339                                      NaN     4878
# 340                                      NaN     1479
# 341                                      NaN     1438
# 342                                      NaN    87232
# 343                                      NaN     1556
# 344                                      NaN      327
# 345                                      NaN     3264
# 346                                      NaN     1371
#
#                                                title_y  \
# 25   Crouching Tiger, Hidden Dragon (Wo hu cang lon...
# 35                                    Halloween (1978)
# 34                                28 Days Later (2002)
# 1                             L.A. Confidential (1997)
# 33                                 12 Angry Men (1957)
# 7                           Princess Bride, The (1987)
# 32                                 Citizen Kane (1941)
# 31                     When a Man Loves a Woman (1994)
# 30    Three Billboards Outside Ebbing, Missouri (2017)
# 29                            Leaving Las Vegas (1995)
# 28                        Sense and Sensibility (1995)
# 27                                      Aladdin (1992)
# 26                          Shakespeare in Love (1998)
# 15                                        Fargo (1996)
# 0                               American Beauty (1999)
# 36   Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 37        My Neighbor Totoro (Tonari no Totoro) (1988)
# 12   Raiders of the Lost Ark (Indiana Jones and the...
# 38                      Godfather: Part II, The (1974)
# 39                                   Adaptation (2002)
# 40                              Green Mile, The (1999)
# 41                                        Logan (2017)
# 19                                    Gladiator (2000)
# 6    Star Wars: Episode VI - Return of the Jedi (1983)
# 14   Star Wars: Episode V - The Empire Strikes Back...
# 42               Dr. Horrible's Sing-Along Blog (2008)
# 43                           Mr. Holland's Opus (1995)
# 44   Spirited Away (Sen to Chihiro no kamikakushi) ...
# 24                         Seven (a.k.a. Se7en) (1995)
# 45                          Lost in Translation (2003)
# ..                                                 ...
# 317                                      Scream (1996)
# 318  Englishman Who Went Up a Hill But Came Down a ...
# 319                                 Client, The (1994)
# 320     Things to Do in Denver When You're Dead (1995)
# 321                                  Paper, The (1994)
# 322                                 Source Code (2011)
# 323                               Happy Gilmore (1996)
# 324                            Book of Eli, The (2010)
# 325                                   True Lies (1994)
# 326                                      Mother (1996)
# 327                                 Chasing Amy (1997)
# 328                                   Bowfinger (1999)
# 329                                  Wind River (2017)
# 330                                      Splash (1984)
# 331                           Kill Bill: Vol. 2 (2004)
# 332                             Dangerous Minds (1995)
# 333  Star Wars: Episode VII - The Force Awakens (2015)
# 334                               Incredibles 2 (2018)
# 335                                Time Bandits (1981)
# 336                     Silver Linings Playbook (2012)
# 337                                    Spy Hard (1996)
# 338                                    Net, The (1995)
# 339                                Donnie Darko (2001)
# 340                                  Saint, The (1997)
# 341                                Dante's Peak (1997)
# 342                          X-Men: First Class (2011)
# 343                     Speed 2: Cruise Control (1997)
# 344                                   Tank Girl (1995)
# 345                    Buffy the Vampire Slayer (1992)
# 346               Star Trek: The Motion Picture (1979)
#
#                                         genres_y  predicted_rating
# 25                          Action|Drama|Romance          5.000000
# 35                                        Horror          5.000000
# 34                          Action|Horror|Sci-Fi          5.000000
# 1               Crime|Film-Noir|Mystery|Thriller          5.000000
# 33                                         Drama          5.000000
# 7        Action|Adventure|Comedy|Fantasy|Romance          5.000000
# 32                                 Drama|Mystery          5.000000
# 31                                 Drama|Romance          5.000000
# 30                                   Crime|Drama          5.000000
# 29                                 Drama|Romance          5.000000
# 28                                 Drama|Romance          5.000000
# 27   Adventure|Animation|Children|Comedy|Musical          5.000000
# 26                          Comedy|Drama|Romance          5.000000
# 15                   Comedy|Crime|Drama|Thriller          5.000000
# 0                                  Drama|Romance          5.000000
# 36                    Adventure|Children|Fantasy          4.886699
# 37              Animation|Children|Drama|Fantasy          4.872022
# 12                              Action|Adventure          4.866430
# 38                                   Crime|Drama          4.861001
# 39                          Comedy|Drama|Romance          4.852610
# 40                                   Crime|Drama          4.846440
# 41                                 Action|Sci-Fi          4.821429
# 19                        Action|Adventure|Drama          4.809555
# 6                        Action|Adventure|Sci-Fi          4.802776
# 14                       Action|Adventure|Sci-Fi          4.787542
# 42                   Comedy|Drama|Musical|Sci-Fi          4.784788
# 43                                         Drama          4.784201
# 44                   Adventure|Animation|Fantasy          4.775069
# 24                              Mystery|Thriller          4.771741
# 45                          Comedy|Drama|Romance          4.767261
# ..                                           ...               ...
# 317               Comedy|Horror|Mystery|Thriller          3.000000
# 318                               Comedy|Romance          3.000000
# 319                       Drama|Mystery|Thriller          3.000000
# 320                          Crime|Drama|Romance          3.000000
# 321                                 Comedy|Drama          3.000000
# 322         Action|Drama|Mystery|Sci-Fi|Thriller          2.993611
# 323                                       Comedy          2.980137
# 324                       Action|Adventure|Drama          2.936700
# 325     Action|Adventure|Comedy|Romance|Thriller          2.927369
# 326                                       Comedy          2.906164
# 327                         Comedy|Drama|Romance          2.906164
# 328                                       Comedy          2.903103
# 329                Action|Crime|Mystery|Thriller          2.788363
# 330                       Comedy|Fantasy|Romance          2.766502
# 331                        Action|Drama|Thriller          2.738796
# 332                                        Drama          2.677328
# 333         Action|Adventure|Fantasy|Sci-Fi|IMAX          2.652588
# 334          Action|Adventure|Animation|Children          2.572183
# 335              Adventure|Comedy|Fantasy|Sci-Fi          2.559155
# 336                                 Comedy|Drama          2.558336
# 337                                       Comedy          2.555791
# 338                        Action|Crime|Thriller          2.523373
# 339                Drama|Mystery|Sci-Fi|Thriller          2.382306
# 340               Action|Romance|Sci-Fi|Thriller          2.000000
# 341                              Action|Thriller          2.000000
# 342         Action|Adventure|Sci-Fi|Thriller|War          1.979274
# 343                      Action|Romance|Thriller          1.525505
# 344                         Action|Comedy|Sci-Fi          1.442902
# 345                         Action|Comedy|Horror          1.327897
# 346                             Adventure|Sci-Fi          1.257616
#
# [347 rows x 7 columns]

# %%
eval_ratings = ratings

def eval_prediction(predict, neighbors=50, kind = 'user'):
    if (kind == 'user'):
        ## evaluation
        ds = pd.merge(eval_ratings, ratings[['movieId','rating']].groupby(['movieId']).mean().reset_index(), 
                      on='movieId', how='left')

        ds = ds.rename(columns= {'rating_x':'rating', 'rating_y':'mean_rating'})
        st = time.time()
        ## udpate to predict_rating 
        user_distance_functions = [('user_euclidean',distance_euclidean), ('user_cosine', distance_cosine)]
        for name, func in user_distance_functions:
            ds[name] = 0
            for user_id in predict:
                # key: movie id, value : predicted_rating
                for x in predictRating(user_id, neighbors, func):
                    ds.loc[(ds.userId == user_id) & (ds.movieId == x[0]),name]=x[1]
        #Only the tuple corresponding to the user performing the predict in the entire dataFrame is returned
        return ds[ds.user_euclidean + ds.user_cosine > 0]

                    
    elif (kind == 'item'):
        ## evaluation
        ds = pd.merge(eval_ratings, ratings[['movieId','rating']].groupby(['movieId']).mean().reset_index(), 
                      on='movieId', how='left')

        ds = ds.rename(columns= {'rating_x':'rating', 'rating_y':'mean_rating'})
        st = time.time()
        ## udpate to predict_rating 
        item_distance_functions = [('item_euclidean', distance_euclidean), ('item_cosine', distance_cosine)]
        for name, func in item_distance_functions:
            ds[name] = 0
            for movie_id in predict:
                for x in predictRating(movie_id, neighbors, func, kind = 'item'):
                    ds.loc[(ds.movieId == movie_id) & (ds.userId == x[0]), name] = x[1]
        return ds[ds.item_euclidean + ds.item_cosine > 0]
    
    print('runtime', round(time.time()-st,2), 'sec')

# %%
## all userId list 
users = user_movie_matrix.index.tolist()
## 10-person star rating
predicted_user = eval_prediction(users[:2], 100, kind = 'user')

predicted_user = predicted_user[(predicted_user['user_cosine'] > 0) & (predicted_user['user_euclidean'] > 0)]

def RMSE(X, left_col, right_col):
    return(np.sqrt(np.mean((X[left_col] - X[right_col])**2)))

def MAE(X, left_col, right_col):
    return(np.mean(np.absolute(X[left_col] - X[right_col])) )

for name in ['mean_rating', 'user_cosine', 'user_euclidean']:
    print ("MAE of {0} is {1} ".format(name, MAE(predicted_user, 'rating', name)))

for name in ['mean_rating', 'user_cosine', 'user_euclidean']:
    print ("RMSE of {0} is {1} ".format(name, RMSE(predicted_user, 'rating', name)))
# Out:
# MAE of mean_rating is 0.7569789978796304
# MAE of user_cosine is 0.5585238059046075
# MAE of user_euclidean is 0.4833899200263817
# RMSE of mean_rating is 0.8872256821133397
# RMSE of user_cosine is 0.6415643926041829
# RMSE of user_euclidean is 0.5984534412106762

# %%
users = user_movie_matrix.index.tolist()
predicted_item = eval_prediction(users[:2], 100, kind = 'item')
predicted_item = predicted_item[(predicted_item['item_cosine'] > 0) & (predicted_item['item_euclidean'] > 0)]

for name in ['mean_rating', 'item_cosine', 'item_euclidean']:
    print ("Item-item MAE of {0} is {1} ".format(name, MAE(predicted_item, 'rating', name)))

for name in ['mean_rating', 'item_cosine', 'item_euclidean']:
    print ("Item-item RMSE of {0} is {1} ".format(name, RMSE(predicted_item, 'rating', name)))
# Out:
# Item-item MAE of mean_rating is 0.5837947986448966
# Item-item MAE of item_cosine is 0.3474639754400428
# Item-item MAE of item_euclidean is 0.10966978989974842
# Item-item RMSE of mean_rating is 0.8076138915772024
# Item-item RMSE of item_cosine is 0.49499308033158385
# Item-item RMSE of item_euclidean is 0.16190065848387944

# %%
predicted_user
# Out:
#      userId  movieId  rating   timestamp  mean_rating  user_euclidean  \
# 0         1        1     4.0   964982703     3.920930        4.302955
# 2         1        6     4.0   964982224     3.946078        4.040658
# 3         1       47     5.0   964983815     3.975369        4.663217
# 4         1       50     5.0   964982931     4.237745        4.618319
# 7         1      110     4.0   964982176     4.031646        4.271191
# 10        1      163     5.0   964983650     3.560606        3.837361
# 11        1      216     5.0   964981208     3.326531        4.510542
# 12        1      223     3.0   964980985     3.855769        4.181818
# 13        1      231     5.0   964981179     3.060150        4.116392
# 15        1      260     5.0   964981680     4.231076        4.644290
# 16        1      296     3.0   964982967     4.197068        3.862645
# 17        1      316     3.0   964982310     3.375000        3.144263
# 18        1      333     5.0   964981179     3.780000        4.250000
# 19        1      349     4.0   964982563     3.604545        3.801814
# 20        1      356     4.0   964980962     4.164134        4.300822
# 21        1      362     5.0   964982588     3.529412        4.558031
# 22        1      367     4.0   964981710     3.184713        4.130943
# 25        1      457     5.0   964981909     3.992105        4.464453
# 26        1      480     4.0   964982346     3.750000        3.552016
# 27        1      500     3.0   964981208     3.388889        3.352437
# 28        1      527     5.0   964984002     4.225000        4.746558
# 32        1      590     4.0   964982546     3.835366        4.351316
# 33        1      592     4.0   964982271     3.428571        3.650406
# 34        1      593     4.0   964983793     4.161290        4.409818
# 36        1      608     5.0   964982931     4.116022        4.755356
# 37        1      648     3.0   964982563     3.537037        3.553363
# 38        1      661     5.0   964982838     3.448980        4.491669
# 40        1      733     4.0   964982400     3.640496        4.011105
# 41        1      736     3.0   964982653     3.321138        3.603184
# 42        1      780     3.0   964984086     3.445545        3.666857
# ..      ...      ...     ...         ...          ...             ...
# 203       1     3147     5.0   964983873     4.148649        4.846440
# 214       1     3448     5.0   964984054     3.802326        4.059531
# 219       1     3578     5.0   964980668     3.938235        4.659381
# 228       1     3793     5.0   964981855     3.699248        4.082298
# 231       1     5060     5.0   964984002     3.934783        4.512355
# 232       2      318     3.0  1445714835     4.429022        4.281186
# 233       2      333     4.0  1445715029     3.780000        4.065082
# 234       2     1704     4.5  1445715228     4.078014        4.238442
# 235       2     3578     4.0  1445714885     3.938235        3.991811
# 236       2     6874     4.0  1445714952     3.961832        4.086520
# 237       2     8798     3.5  1445714960     3.761364        3.662452
# 238       2    46970     4.0  1445715013     3.250000        3.446627
# 239       2    48516     4.0  1445715064     4.252336        4.229200
# 240       2    58559     4.5  1445715141     4.238255        4.253397
# 242       2    68157     4.5  1445715154     4.136364        4.250939
# 243       2    71535     3.0  1445714974     3.877358        3.589923
# 244       2    74458     4.0  1445714926     4.022388        4.203711
# 245       2    77455     3.0  1445714941     4.038462        3.665897
# 246       2    79132     4.0  1445714841     4.066434        4.213210
# 247       2    80489     4.5  1445715340     3.954545        4.020342
# 248       2    80906     5.0  1445715172     4.291667        4.763018
# 249       2    86345     4.0  1445715166     4.055556        4.197837
# 251       2    91529     3.5  1445714891     3.993421        4.096750
# 252       2    91658     2.5  1445714938     3.488095        2.190096
# 253       2    99114     3.5  1445714874     3.943662        4.229232
# 254       2   106782     5.0  1445714966     3.916667        4.045082
# 255       2   109487     3.0  1445715145     3.993151        4.097247
# 256       2   112552     4.0  1445714882     4.039474        4.277214
# 258       2   115713     3.5  1445714854     3.910714        4.500000
# 259       2   122882     5.0  1445715272     3.819149        4.668403
#
#      user_cosine
# 0       4.067384
# 2       4.500137
# 3       4.480351
# 4       4.520947
# 7       4.210624
# 10      3.998374
# 11      4.168315
# 12      3.401123
# 13      4.416107
# 15      4.462436
# 16      4.273903
# 17      3.713849
# 18      3.999101
# 19      3.562832
# 20      4.148587
# 21      4.502011
# 22      3.600877
# 25      4.286558
# 26      3.884168
# 27      3.249039
# 28      4.576397
# 32      4.154422
# 33      3.999558
# 34      4.236105
# 36      4.500898
# 37      3.500726
# 38      4.247696
# 40      4.749978
# 41      3.748493
# 42      3.777067
# ..           ...
# 203     4.500327
# 214     4.750196
# 219     4.326842
# 228     3.730810
# 231     4.250041
# 232     4.381241
# 233     4.150404
# 234     4.422737
# 235     4.142259
# 236     4.245354
# 237     3.943909
# 238     3.666785
# 239     4.459574
# 240     4.443428
# 242     4.315247
# 243     3.929882
# 244     4.327769
# 245     3.749715
# 246     4.406365
# 247     4.063164
# 248     4.584101
# 249     4.699360
# 251     4.200730
# 252     3.831595
# 253     4.326872
# 254     4.617901
# 255     4.106783
# 256     4.293128
# 258     4.250177
# 259     4.500732
#
# [106 rows x 7 columns]

# %%
k_array = [5, 15, 30, 50, 100, 200]
user_mean_MAE = []
user_mean_RMSE = []
user_cosine_MAE = []
user_cosine_RMSE = []
user_euc_MAE = []
user_euc_RMSE = []

for k in k_array:
    predicted_user = eval_prediction(users[:2], k, kind = 'user')

    predicted_user = predicted_user[(predicted_user['user_cosine'] > 0) & (predicted_user['user_euclidean'] > 0)]
    
    for name in ['mean_rating', 'user_cosine', 'user_euclidean']:
        if (name == 'mean_rating'):
            user_mean_MAE.append(MAE(predicted_user, 'rating', name))
            user_mean_RMSE.append(RMSE(predicted_user, 'rating', name))
        elif (name == 'user_cosine'):
            user_cosine_MAE.append(MAE(predicted_user, 'rating', name))
            user_cosine_RMSE.append(RMSE(predicted_user, 'rating', name))
        elif (name == 'user_euclidean'):
            user_euc_MAE.append(MAE(predicted_user, 'rating', name))
            user_euc_RMSE.append(RMSE(predicted_user, 'rating', name))

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pal = sns.color_palette("Set2", 3)
plt.figure(figsize=(8, 8))
plt.plot(k_array, user_mean_MAE, c=pal[0], label='User mean MAE', linewidth=5)
plt.plot(k_array, user_cosine_MAE, c=pal[1], label='User cosine MAE', linewidth=5)
plt.plot(k_array, user_euc_MAE, c=pal[2], label='User euclidean MAE', linewidth=5)
plt.legend(loc='best', fontsize=20)
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
plt.xlabel('k', fontsize=30);
plt.ylabel('MAE', fontsize=30);

# %%
sns.set()

pal = sns.color_palette("Set2", 3)
plt.figure(figsize=(8, 8))
plt.plot(k_array, user_mean_RMSE, c=pal[0], label='User mean RMSE', linewidth=5)
plt.plot(k_array, user_cosine_RMSE, c=pal[1], label='User cosine RMSE', linewidth=5)
plt.plot(k_array, user_euc_RMSE, c=pal[2], label='User euclidean RMSE', linewidth=5)
plt.legend(loc='best', fontsize=20)
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
plt.xlabel('k', fontsize=30);
plt.ylabel('RMSE', fontsize=30);

# %%
k_array = [5, 15, 30, 50, 100, 200]
item_mean_MAE = []
item_mean_RMSE = []
item_cosine_MAE = []
item_cosine_RMSE = []
item_euc_MAE = []
item_euc_RMSE = []

for k in k_array:
    predicted_item = eval_prediction(users[:5], k, kind = 'item')

    predicted_item = predicted_item[(predicted_item['item_cosine'] > 0) & (predicted_item['item_euclidean'] > 0)]
    
    for name in ['mean_rating', 'item_cosine', 'item_euclidean']:
        if (name == 'mean_rating'):
            item_mean_MAE.append(MAE(predicted_item, 'rating', name))
            item_mean_RMSE.append(RMSE(predicted_item, 'rating', name))
        elif (name == 'item_cosine'):
            item_cosine_MAE.append(MAE(predicted_item, 'rating', name))
            item_cosine_RMSE.append(RMSE(predicted_item, 'rating', name))
        elif (name == 'item_euclidean'):
            item_euc_MAE.append(MAE(predicted_item, 'rating', name))
            item_euc_RMSE.append(RMSE(predicted_item, 'rating', name))

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pal = sns.color_palette("Set2", 3)
plt.figure(figsize=(8, 8))
plt.plot(k_array, item_mean_MAE, c=pal[0], label='item mean MAE', linewidth=5)
plt.plot(k_array, item_cosine_MAE, c=pal[1], label='item cosine MAE', linewidth=5)
plt.plot(k_array, item_euc_MAE, c=pal[2], label='item euclidean MAE', linewidth=5)
plt.legend(loc='best', fontsize=20)
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
plt.xlabel('k', fontsize=30);
plt.ylabel('MAE', fontsize=30);

# %%
sns.set()

pal = sns.color_palette("Set2", 3)
plt.figure(figsize=(8, 8))
plt.plot(k_array, item_mean_RMSE, c=pal[0], label='item mean RMSE', linewidth=5)
plt.plot(k_array, item_cosine_RMSE, c=pal[1], label='item cosine RMSE', linewidth=5)
plt.plot(k_array, item_euc_RMSE, c=pal[2], label='item euclidean RMSE', linewidth=5)
plt.legend(loc='best', fontsize=20)
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
plt.xlabel('k', fontsize=30);
plt.ylabel('RMSE', fontsize=30);
