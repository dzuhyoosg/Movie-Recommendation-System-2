# %%
import pandas as pd
import numpy as np
import time

# %%
ratings = pd.read_csv("./ml-latest-small/ratings.csv")
ratings[ratings.userId==2].head(20)
# Out:
#      userId  movieId  rating   timestamp
# 232       2      318     3.0  1445714835
# 233       2      333     4.0  1445715029
# 234       2     1704     4.5  1445715228
# 235       2     3578     4.0  1445714885
# 236       2     6874     4.0  1445714952
# 237       2     8798     3.5  1445714960
# 238       2    46970     4.0  1445715013
# 239       2    48516     4.0  1445715064
# 240       2    58559     4.5  1445715141
# 241       2    60756     5.0  1445714980
# 242       2    68157     4.5  1445715154
# 243       2    71535     3.0  1445714974
# 244       2    74458     4.0  1445714926
# 245       2    77455     3.0  1445714941
# 246       2    79132     4.0  1445714841
# 247       2    80489     4.5  1445715340
# 248       2    80906     5.0  1445715172
# 249       2    86345     4.0  1445715166
# 250       2    89774     5.0  1445715189
# 251       2    91529     3.5  1445714891

# %%
movies = pd.read_csv('./ml-latest/movies.csv', encoding='latin-1')
print (movies.shape)
movies.head()
# Out:
# (58098, 3)
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
num_users = ratings.userId.unique().shape[0]
num_items = ratings.movieId.unique().shape[0]
num_users, num_items
# Out:
# (610, 9724)

# %%
from sklearn import model_selection as ms
train_set, test_set = ms.train_test_split(ratings, test_size=0.25)
len(train_set), len(test_set)
# Out:
# (75627, 25209)

# %%
UM_matrix_ds = ratings.pivot(index='userId', columns='movieId', values='rating')
print("UM Matrix value size", UM_matrix_ds.values.size)
print("ratings value size", ratings.values.size)
print("Sparisity: {:4.2f}%".format(ratings.rating.values.size/UM_matrix_ds.values.size*100))
UM_matrix_ds.head(10)
# Out:
# UM Matrix value size 5931640
# ratings value size 403344
# Sparisity: 1.70%
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6           NaN     4.0     5.0     3.0     5.0     4.0     4.0     3.0
# 7           4.5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8           NaN     4.0     NaN     NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10       ...    193565  193567  193571  193573  193579  \
# userId                    ...
# 1           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 6           NaN     3.0   ...       NaN     NaN     NaN     NaN     NaN
# 7           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 8           NaN     2.0   ...       NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
#
# movieId  193581  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN
# 6           NaN     NaN     NaN     NaN     NaN
# 7           NaN     NaN     NaN     NaN     NaN
# 8           NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN     NaN     NaN     NaN
#
# [10 rows x 9724 columns]

# %%
# similarity
import math
from operator import itemgetter
from scipy.spatial import distance

def distance_cosine(a,b):
    return 1-distance.cosine(a,b)

def disance_corr(a,b):
    return 1-distance.correlation(a,b)

def distance_euclidean(a,b):
    return 1/(distance.euclidean(a,b)+1)

# %%
def nearest_neighbor_user(user, topN, simFunc) :  
    u1 = UM_matrix_ds.loc[user].dropna()
    ratedIndex = u1.index
    nn = {}
    
    # Brute-Force Compute
    for uid, row in UM_matrix_ds.iterrows():
        interSectionU1 = []
        interSectionU2 = []
        if uid==user:
            continue
            
        for i in ratedIndex:
            if False==math.isnan(row[i]):
                interSectionU1.append(u1[i])
                interSectionU2.append(row[i])
        interSectionLen = len(interSectionU1)
        
        # at least 3 intersection items
        if interSectionLen < 3 :
            continue
            
        # similarity functon
        sim = simFunc(interSectionU1, interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[uid] = sim
            
    # top N returned         
    return sorted(nn.items(),key=itemgetter(1),reverse=True)[:(topN+1)]
    #return sorted(nn.items(),key=itemgetter(1))[:-(topN+1):-1]

# %%
def nearest_neighbor_item(movie, topN, simFunc):
    m1 = UM_matrix_ds[movie].dropna()
    user_index = m1.index
    nn = {}
    
    for movieId, col in UM_matrix_ds.iteritems():
        interSectionU1 = []
        interSectionU2 = []
        if movie == movieId:
            continue
        
        for i in user_index:
            if False==math.isnan(col[i]):
                interSectionU1.append(m1[i])
                interSectionU2.append(col[i])
        interSectionLen = len(interSectionU1)
        # at least 3 intersection items
        if interSectionLen < 3 :
            continue
            
        # similarity functon
        sim = simFunc(interSectionU1, interSectionU2)
        
        if  math.isnan(sim) == False:
            nn[movieId] = sim
            
    # top N returned         
    return sorted(nn.items(),key=itemgetter(1),reverse=True)[:(topN+1)]

# %%
print(pd.DataFrame(nearest_neighbor_user(278, 100, distance_euclidean), columns=['userId', 'sim']))
print(pd.DataFrame(nearest_neighbor_item(1, 100, distance_euclidean), columns=['movieId', 'sim']))
# Out:
#      userId       sim
# 0         8  1.000000
# 1        15  1.000000
# 2       348  1.000000
# 3       352  1.000000
# 4       373  1.000000
# 5       382  1.000000
# 6       512  1.000000
# 7       566  1.000000
# 8       601  1.000000
# 9       602  1.000000
# 10        1  0.666667
# 11      296  0.666667
# 12      338  0.666667
# 13      484  0.666667
# 14      515  0.666667
# 15      572  0.666667
# 16       17  0.585786
# 17       59  0.585786
# 18       72  0.585786
# 19      178  0.585786
# 20      232  0.585786
# 21      254  0.585786
# 22      280  0.585786
# 23      282  0.585786
# 24      330  0.585786
# 25      343  0.585786
# 26      415  0.585786
# 27      418  0.585786
# 28      489  0.585786
# 29      587  0.585786
# ..      ...       ...
# 71      200  0.387426
# 72      202  0.387426
# 73      219  0.387426
# 74      239  0.387426
# 75      249  0.387426
# 76      152  0.376179
# 77      420  0.376179
# 78      590  0.376179
# 79      356  0.366025
# 80      105  0.356789
# 81      318  0.356789
# 82      434  0.356789
# 83      452  0.356789
# 84      552  0.356789
# 85      212  0.348331
# 86      103  0.340542
# 87      290  0.340542
# 88      331  0.333333
# 89      453  0.333333
# 90      455  0.333333
# 91      580  0.333333
# 92      265  0.326632
# 93      469  0.326632
# 94      111  0.320377
# 95      167  0.320377
# 96      275  0.320377
# 97      357  0.320377
# 98        5  0.309017
# 99       60  0.309017
# 100     109  0.309017
#
# [101 rows x 2 columns]
#      movieId       sim
# 0       1484  1.000000
# 1       2932  1.000000
# 2       2940  1.000000
# 3       2967  1.000000
# 4       2988  1.000000
# 5       3111  1.000000
# 6       3384  1.000000
# 7       4745  1.000000
# 8       5833  1.000000
# 9       5876  1.000000
# 10      7766  1.000000
# 11    178061  1.000000
# 12       482  0.666667
# 13       949  0.666667
# 14      1082  0.666667
# 15      1192  0.666667
# 16      1447  0.666667
# 17      2553  0.666667
# 18      2971  0.666667
# 19      3117  0.666667
# 20      3412  0.666667
# 21      3724  0.666667
# 22      4220  0.666667
# 23      4713  0.666667
# 24      5039  0.666667
# 25      6041  0.666667
# 26      6636  0.666667
# 27      6639  0.666667
# 28      7048  0.666667
# 29     26528  0.666667
# ..       ...       ...
# 71    162578  0.585786
# 72      3545  0.535898
# 73      3871  0.535898
# 74      4846  0.535898
# 75      4889  0.535898
# 76      4954  0.535898
# 77      5298  0.535898
# 78      5483  0.535898
# 79      7285  0.535898
# 80      7303  0.535898
# 81      8008  0.535898
# 82     26903  0.535898
# 83     30820  0.535898
# 84     33677  0.535898
# 85     40414  0.535898
# 86     45440  0.535898
# 87     49132  0.535898
# 88     49910  0.535898
# 89     80586  0.535898
# 90     96655  0.535898
# 91     98124  0.535898
# 92    158238  0.535898
# 93    180031  0.535898
# 94       233  0.500000
# 95       944  0.500000
# 96       948  0.500000
# 97      1050  0.500000
# 98      1051  0.500000
# 99      1177  0.500000
# 100     1332  0.500000
#
# [101 rows x 2 columns]

# %%
def predictRating(id_num, nn=50, simFunc=distance_euclidean, kind = 'user') :
   
    if (kind == "user"):
        ## neighboorhood 
        neighbor = nearest_neighbor_user(id_num, nn, simFunc)
        # userid: dictionary of similarity

        neighbor_id = [id for id, sim in neighbor]
        # List of similar similarities

        ## Remove if four or more are NaN
        neighbor_movie = UM_matrix_ds.loc[neighbor_id].dropna(1, how = 'all', thresh = 4)
        # User id x DataFrame of movie id. However, if the NaN of the column is 4 or more, it is deleted.

        neighbor_dic = (dict(neighbor))
        ret = [] #['movieId', 'predictedRate']

        # iterate through each column key: userid, column: movieid, value: rating
        for movieId, row in neighbor_movie.iteritems():
            jsum, wsum = 0, 0
            for v in row.dropna().iteritems():
                sim = neighbor_dic.get(v[0],0)
                jsum += sim
                wsum += (v[1]*sim)
            ret.append([movieId, wsum/jsum])

        return ret
    
    elif (kind == 'item'):
        neighbor = nearest_neighbor_item(id_num, nn, simFunc)
        
        neighbor_id = [id for id, sim in neighbor]
        
        neighbor_ratedUser = UM_matrix_ds[neighbor_id].dropna(0, how = 'all', thresh = 4)
        
        neighbor_dic = dict(neighbor)
        ret = []
        
        for userId, row in neighbor_ratedUser.iterrows():
            jsum, wsum = 0, 0
            for v in row.dropna().iteritems():
                sim = neighbor_dic.get(v[0], 0)
                jsum += sim
                wsum += (v[1]*sim)
            ret.append([userId, wsum/jsum])
        
        return ret

# %%
predictRating(10, 50, kind = 'user')
# predictRating(1, 50, kind = 'item')
# Out:
# [[1, 3.950267484592048],
#  [2, 3.979811986075693],
#  [3, 3.7627161241490796],
#  [5, 3.383238977624035],
#  [6, 3.623842151924668],
#  [7, 3.544298112964249],
#  [10, 3.278438634105372],
#  [11, 4.218009787879696],
#  [15, 3.1087378374683117],
#  [16, 3.2752866066870943],
#  [17, 3.715749533510972],
#  [19, 2.805939205324938],
#  [21, 2.6872527010478597],
#  [22, 3.726903174436542],
#  [24, 3.4761302011691093],
#  [31, 3.191573551445447],
#  [32, 3.5042768181876873],
#  [34, 4.057807531359828],
#  [36, 4.0],
#  [39, 3.352792594329325],
#  [41, 3.6871664255542154],
#  [45, 3.0],
#  [47, 3.185412191529095],
#  [48, 3.5505204425115138],
#  [50, 3.7719146614612225],
#  [2161, 4.1525862677736125],
#  [2174, 2.755858847957929],
#  [2355, 3.5167081459247154],
#  [2396, 4.0],
#  [2529, 3.0857027997246522],
#  [2542, 3.6583038203980505],
#  [2657, 3.3098798198614396],
#  [2671, 3.2653714023070464],
#  [2694, 3.3484950389872243],
#  [2797, 3.6854122144904182],
#  [2858, 2.4366813040098645],
#  [2944, 4.507712245782865],
#  [2987, 2.7101043238733227],
#  [3448, 4.242283733359965],
#  [3450, 3.594827256475591],
#  [3504, 3.4902045769542034],
#  [3552, 4.236305269375596],
#  [3671, 3.951103989805892],
#  [3751, 3.4818430776745632],
#  [4226, 3.9047805509432085],
#  [4306, 4.42004331848954],
#  [4308, 4.492707208565863],
#  [4963, 4.230342138670162],
#  [4993, 4.40811769489283],
#  [4995, 4.65302736479388],
#  [5218, 4.133842635979494],
#  [5952, 4.214857292176656],
#  [6539, 4.008121739874953],
#  [7153, 4.320946979920835],
#  [8360, 4.003910351180071],
#  [8368, 3.4131923008360303]]

# %%
## view rated movies and movies with high ratings
def ratingMovies(user_id):
    ds = pd.merge(ratings[ratings.userId==user_id], movies, on=['movieId'])
    return ds.sort_values(by=['rating'], ascending=False)[['rating','title','genres','movieId']].head(100)
ratingMovies(1).head()
# Out:
#      rating                                      title  \
# 231     5.0               M*A*S*H (a.k.a. MASH) (1970)
# 185     5.0                           Excalibur (1981)
# 89      5.0  Indiana Jones and the Last Crusade (1989)
# 90      5.0                Pink Floyd: The Wall (1982)
# 190     5.0               From Russia with Love (1963)
#
#                         genres  movieId
# 231           Comedy|Drama|War     5060
# 185          Adventure|Fantasy     2872
# 89            Action|Adventure     1291
# 90               Drama|Musical     1298
# 190  Action|Adventure|Thriller     2948

# %%
def join_movie_info(predicted_result):
    predicted_ratings = pd.DataFrame(predicted_result, columns=['movieId', 'predicted_rating'])
    result_ds = pd.merge(movies[movies.movieId > 0], predicted_ratings, on=['movieId'])
    return result_ds.sort_values(by=['predicted_rating'], ascending=False)

result_user = predictRating(50, kind = 'user')
result_item = predictRating(1, kind = 'item')
join_movie_info(result_user).head(10)
# Out:
#      movieId                                              title  \
# 57       260          Star Wars: Episode IV - A New Hope (1977)
# 140     1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 142     1356                    Star Trek: First Contact (1996)
# 77       357                 Four Weddings and a Funeral (1994)
# 118      608                                       Fargo (1996)
# 141     1214                                       Alien (1979)
# 69       318                   Shawshank Redemption, The (1994)
# 7         11                     American President, The (1995)
# 9         16                                      Casino (1995)
# 16        36                            Dead Man Walking (1995)
#
#                                genres  predicted_rating
# 57            Action|Adventure|Sci-Fi          4.389825
# 140           Action|Adventure|Sci-Fi          4.378229
# 142  Action|Adventure|Sci-Fi|Thriller          4.306830
# 77                     Comedy|Romance          4.238537
# 118       Comedy|Crime|Drama|Thriller          4.238281
# 141                     Horror|Sci-Fi          4.166206
# 69                        Crime|Drama          4.154359
# 7                Comedy|Drama|Romance          4.147632
# 9                         Crime|Drama          4.122993
# 16                        Crime|Drama          4.086745

# %%
join_movie_info(result_item).head(10)
# Out:
#    movieId                             title  \
# 5      380                  True Lies (1994)
# 2      249           Immortal Beloved (1994)
# 1      182    Moonlight and Valentino (1995)
# 3      290         Once Were Warriors (1994)
# 9      603              Bye Bye, Love (1995)
# 6      414          Air Up There, The (1994)
# 7      474        In the Line of Fire (1993)
# 4      318  Shawshank Redemption, The (1994)
# 0      140      Up Close and Personal (1996)
# 8      599            Wild Bunch, The (1969)
#
#                                      genres  predicted_rating
# 5  Action|Adventure|Comedy|Romance|Thriller          5.000000
# 2                             Drama|Romance          4.400000
# 1                             Drama|Romance          4.096215
# 3                               Crime|Drama          4.000000
# 9                                    Comedy          4.000000
# 6                                    Comedy          3.980591
# 7                           Action|Thriller          3.789569
# 4                               Crime|Drama          3.125000
# 0                             Drama|Romance          3.116928
# 8                         Adventure|Western          2.897704

# %%
# 5th user's star rating
userId=1
pd.merge(ratingMovies(userId), join_movie_info(predictRating(userId)), 
         on=['movieId'], how='right').sort_values(by=['predicted_rating'], ascending =False)
# Out:
#      rating                                            title_x  \
# 3       5.0                         Princess Bride, The (1987)
# 12      NaN                                                NaN
# 0       5.0                             American Beauty (1999)
# 13      NaN                                                NaN
# 6       5.0  Raiders of the Lost Ark (Indiana Jones and the...
# 14      NaN                                                NaN
# 8       5.0                                   Gladiator (2000)
# 15      NaN                                                NaN
# 11      5.0                        Seven (a.k.a. Se7en) (1995)
# 16      NaN                                                NaN
# 7       5.0                            Schindler's List (1993)
# 9       5.0          Star Wars: Episode IV - A New Hope (1977)
# 17      NaN                                                NaN
# 18      NaN                                                NaN
# 19      NaN                                                NaN
# 20      NaN                                                NaN
# 21      NaN                                                NaN
# 22      NaN                                                NaN
# 23      NaN                                                NaN
# 10      5.0                         Usual Suspects, The (1995)
# 5       5.0                                 Matrix, The (1999)
# 24      NaN                                                NaN
# 25      NaN                                                NaN
# 26      NaN                                                NaN
# 27      NaN                                                NaN
# 28      NaN                                                NaN
# 29      NaN                                                NaN
# 30      NaN                                                NaN
# 31      NaN                                                NaN
# 32      NaN                                                NaN
# ..      ...                                                ...
# 78      NaN                                                NaN
# 79      NaN                                                NaN
# 80      NaN                                                NaN
# 81      NaN                                                NaN
# 82      NaN                                                NaN
# 83      NaN                                                NaN
# 84      NaN                                                NaN
# 85      NaN                                                NaN
# 86      NaN                                                NaN
# 87      NaN                                                NaN
# 88      NaN                                                NaN
# 89      NaN                                                NaN
# 90      NaN                                                NaN
# 91      NaN                                                NaN
# 92      NaN                                                NaN
# 93      NaN                                                NaN
# 94      NaN                                                NaN
# 95      NaN                                                NaN
# 96      NaN                                                NaN
# 97      NaN                                                NaN
# 98      NaN                                                NaN
# 99      NaN                                                NaN
# 100     NaN                                                NaN
# 101     NaN                                                NaN
# 102     NaN                                                NaN
# 103     NaN                                                NaN
# 104     NaN                                                NaN
# 105     NaN                                                NaN
# 106     NaN                                                NaN
# 107     NaN                                                NaN
#
#                                     genres_x  movieId  \
# 3    Action|Adventure|Comedy|Fantasy|Romance     1197
# 12                                       NaN      588
# 0                              Drama|Romance     2858
# 13                                       NaN     4896
# 6                           Action|Adventure     1198
# 14                                       NaN     3147
# 8                     Action|Adventure|Drama     3578
# 15                                       NaN     5618
# 11                          Mystery|Thriller       47
# 16                                       NaN   112552
# 7                                  Drama|War      527
# 9                    Action|Adventure|Sci-Fi      260
# 17                                       NaN      318
# 18                                       NaN    81834
# 19                                       NaN     2324
# 20                                       NaN    89745
# 21                                       NaN    60069
# 22                                       NaN    58559
# 23                                       NaN      364
# 10                    Crime|Mystery|Thriller       50
# 5                     Action|Sci-Fi|Thriller     2571
# 24                                       NaN    76093
# 25                                       NaN     5816
# 26                                       NaN     4995
# 27                                       NaN   112852
# 28                                       NaN     8961
# 29                                       NaN    91529
# 30                                       NaN    68954
# 31                                       NaN    33794
# 32                                       NaN   109487
# ..                                       ...      ...
# 78                                       NaN      589
# 79                                       NaN    99114
# 80                                       NaN     4022
# 81                                       NaN    44191
# 82                                       NaN     6539
# 83                                       NaN   134130
# 84                                       NaN     7361
# 85                                       NaN    70286
# 86                                       NaN     4306
# 87                                       NaN     1036
# 88                                       NaN     6942
# 89                                       NaN     1584
# 90                                       NaN     4973
# 91                                       NaN      592
# 92                                       NaN     4226
# 93                                       NaN    49272
# 94                                       NaN     5989
# 95                                       NaN     5445
# 96                                       NaN    77561
# 97                                       NaN      783
# 98                                       NaN      597
# 99                                       NaN   122916
# 100                                      NaN   176371
# 101                                      NaN    54286
# 102                                      NaN     1485
# 103                                      NaN      296
# 104                                      NaN      300
# 105                                      NaN      329
# 106                                      NaN     1597
# 107                                      NaN     2770
#
#                                                title_y  \
# 3                           Princess Bride, The (1987)
# 12                                      Aladdin (1992)
# 0                               American Beauty (1999)
# 13   Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 6    Raiders of the Lost Ark (Indiana Jones and the...
# 14                              Green Mile, The (1999)
# 8                                     Gladiator (2000)
# 15   Spirited Away (Sen to Chihiro no kamikakushi) ...
# 11                         Seven (a.k.a. Se7en) (1995)
# 16                                     Whiplash (2014)
# 7                              Schindler's List (1993)
# 9            Star Wars: Episode IV - A New Hope (1977)
# 17                    Shawshank Redemption, The (1994)
# 18   Harry Potter and the Deathly Hallows: Part 1 (...
# 19         Life Is Beautiful (La Vita Ã¨ bella) (1997)
# 20                                Avengers, The (2012)
# 21                                      WALLÂ·E (2008)
# 22                             Dark Knight, The (2008)
# 23                               Lion King, The (1994)
# 10                          Usual Suspects, The (1995)
# 5                                   Matrix, The (1999)
# 24                     How to Train Your Dragon (2010)
# 25      Harry Potter and the Chamber of Secrets (2002)
# 26                            Beautiful Mind, A (2001)
# 27                      Guardians of the Galaxy (2014)
# 28                             Incredibles, The (2004)
# 29                       Dark Knight Rises, The (2012)
# 30                                           Up (2009)
# 31                                Batman Begins (2005)
# 32                                 Interstellar (2014)
# ..                                                 ...
# 78                   Terminator 2: Judgment Day (1991)
# 79                             Django Unchained (2012)
# 80                                    Cast Away (2000)
# 81                               V for Vendetta (2006)
# 82   Pirates of the Caribbean: The Curse of the Bla...
# 83                                  The Martian (2015)
# 84        Eternal Sunshine of the Spotless Mind (2004)
# 85                                   District 9 (2009)
# 86                                        Shrek (2001)
# 87                                     Die Hard (1988)
# 88                                Love Actually (2003)
# 89                                      Contact (1997)
# 90   Amelie (Fabuleux destin d'AmÃ©lie Poulain, Le)...
# 91                                       Batman (1989)
# 92                                      Memento (2000)
# 93                                Casino Royale (2006)
# 94                          Catch Me If You Can (2002)
# 95                              Minority Report (2002)
# 96                                   Iron Man 2 (2010)
# 97                 Hunchback of Notre Dame, The (1996)
# 98                                 Pretty Woman (1990)
# 99                               Thor: Ragnarok (2017)
# 100                           Blade Runner 2049 (2017)
# 101                       Bourne Ultimatum, The (2007)
# 102                                   Liar Liar (1997)
# 103                                Pulp Fiction (1994)
# 104                                   Quiz Show (1994)
# 105                      Star Trek: Generations (1994)
# 106                           Conspiracy Theory (1997)
# 107                                   Bowfinger (1999)
#
#                                               genres_y  predicted_rating
# 3              Action|Adventure|Comedy|Fantasy|Romance          5.000000
# 12         Adventure|Animation|Children|Comedy|Musical          5.000000
# 0                                        Drama|Romance          5.000000
# 13                          Adventure|Children|Fantasy          4.886699
# 6                                     Action|Adventure          4.866430
# 14                                         Crime|Drama          4.846440
# 8                               Action|Adventure|Drama          4.809555
# 15                         Adventure|Animation|Fantasy          4.775069
# 11                                    Mystery|Thriller          4.771741
# 16                                               Drama          4.764554
# 7                                            Drama|War          4.763479
# 9                              Action|Adventure|Sci-Fi          4.760956
# 17                                         Crime|Drama          4.727501
# 18                       Action|Adventure|Fantasy|IMAX          4.723981
# 19                            Comedy|Drama|Romance|War          4.705324
# 20                        Action|Adventure|Sci-Fi|IMAX          4.701064
# 21         Adventure|Animation|Children|Romance|Sci-Fi          4.699275
# 22                             Action|Crime|Drama|IMAX          4.692279
# 23     Adventure|Animation|Children|Drama|Musical|IMAX          4.687773
# 10                              Crime|Mystery|Thriller          4.685336
# 5                               Action|Sci-Fi|Thriller          4.674731
# 24           Adventure|Animation|Children|Fantasy|IMAX          4.663630
# 25                                   Adventure|Fantasy          4.644966
# 26                                       Drama|Romance          4.641579
# 27                             Action|Adventure|Sci-Fi          4.637824
# 28          Action|Adventure|Animation|Children|Comedy          4.626750
# 29                         Action|Adventure|Crime|IMAX          4.620746
# 30                  Adventure|Animation|Children|Drama          4.616225
# 31                                   Action|Crime|IMAX          4.568219
# 32                                         Sci-Fi|IMAX          4.561538
# ..                                                 ...               ...
# 78                                       Action|Sci-Fi          4.005546
# 79                                Action|Drama|Western          3.993195
# 80                                               Drama          3.977610
# 81                         Action|Sci-Fi|Thriller|IMAX          3.976781
# 82                     Action|Adventure|Comedy|Fantasy          3.970884
# 83                              Adventure|Drama|Sci-Fi          3.967911
# 84                                Drama|Romance|Sci-Fi          3.949682
# 85                             Mystery|Sci-Fi|Thriller          3.868553
# 86   Adventure|Animation|Children|Comedy|Fantasy|Ro...          3.846849
# 87                               Action|Crime|Thriller          3.838089
# 88                                Comedy|Drama|Romance          3.832325
# 89                                        Drama|Sci-Fi          3.817914
# 90                                      Comedy|Romance          3.782274
# 91                               Action|Crime|Thriller          3.781819
# 92                                    Mystery|Thriller          3.751220
# 93                           Action|Adventure|Thriller          3.749565
# 94                                         Crime|Drama          3.748497
# 95                Action|Crime|Mystery|Sci-Fi|Thriller          3.735333
# 96               Action|Adventure|Sci-Fi|Thriller|IMAX          3.703729
# 97            Animation|Children|Drama|Musical|Romance          3.650914
# 98                                      Comedy|Romance          3.602626
# 99                             Action|Adventure|Sci-Fi          3.558539
# 100                                             Sci-Fi          3.519760
# 101                              Action|Crime|Thriller          3.510002
# 102                                             Comedy          3.505875
# 103                        Comedy|Crime|Drama|Thriller          3.496495
# 104                                              Drama          3.239579
# 105                             Adventure|Drama|Sci-Fi          3.230377
# 106                     Drama|Mystery|Romance|Thriller          3.087359
# 107                                             Comedy          2.903103
#
# [108 rows x 7 columns]

# %%
eval_ratings = ratings

def eval_prediction(predict_users, n_users=50):
    ## evaluation
    ds = pd.merge(eval_ratings, ratings[['movieId','rating']].groupby(['movieId']).mean().reset_index(), 
                  on='movieId', how='left')

    ds = ds.rename(columns= {'rating_x':'rating', 'rating_y':'mean_rating'})
    print (ds)
    st = time.time()
    ## udpate to predict_rating 
    distance_functions = [('euclidean',distance_euclidean), ('cosine', distance_cosine)]
    for name, func in distance_functions:
        ds[name] = 0
        for user_id in predict_users:
            # key: movie id, value : predicted_rating
            for x in predictRating(user_id, n_users, func):
                ds.loc[(ds.userId==user_id) & (ds.movieId==x[0]),name]=x[1]
    print('runtime', round(time.time()-st,2), 'sec')
    #Only the tuple corresponding to the user performing the predict in the entire dataFrame is returned
    return ds[ds.euclidean+ds.cosine>0]

# %%
## all userId list 
users = UM_matrix_ds.index.tolist()
## 10-person star rating
predicted = eval_prediction(users[:50], 20)
predicted
# Out:
#         userId  movieId  rating   timestamp  mean_rating
# 0            1        1     4.0   964982703     3.920930
# 1            1        3     4.0   964981247     3.259615
# 2            1        6     4.0   964982224     3.946078
# 3            1       47     5.0   964983815     3.975369
# 4            1       50     5.0   964982931     4.237745
# 5            1       70     3.0   964982400     3.509091
# 6            1      101     5.0   964980868     3.782609
# 7            1      110     4.0   964982176     4.031646
# 8            1      151     5.0   964984041     3.545455
# 9            1      157     5.0   964984100     2.863636
# 10           1      163     5.0   964983650     3.560606
# 11           1      216     5.0   964981208     3.326531
# 12           1      223     3.0   964980985     3.855769
# 13           1      231     5.0   964981179     3.060150
# 14           1      235     4.0   964980908     3.678571
# 15           1      260     5.0   964981680     4.231076
# 16           1      296     3.0   964982967     4.197068
# 17           1      316     3.0   964982310     3.375000
# 18           1      333     5.0   964981179     3.780000
# 19           1      349     4.0   964982563     3.604545
# 20           1      356     4.0   964980962     4.164134
# 21           1      362     5.0   964982588     3.529412
# 22           1      367     4.0   964981710     3.184713
# 23           1      423     3.0   964982363     2.850000
# 24           1      441     4.0   964980868     3.928571
# 25           1      457     5.0   964981909     3.992105
# 26           1      480     4.0   964982346     3.750000
# 27           1      500     3.0   964981208     3.388889
# 28           1      527     5.0   964984002     4.225000
# 29           1      543     4.0   964981179     3.317073
# ...        ...      ...     ...         ...          ...
# 100806     610   150401     3.0  1479543210     3.000000
# 100807     610   152077     4.0  1493845817     3.678571
# 100808     610   152081     4.0  1493846503     3.890625
# 272        3     1275     3.5  1306463323     3.729167   3.913931  0.000000
# 274        3     1371     3.0  1306463561     3.044444   3.070051  0.000000
# 275        3     1587     4.5  1306464003     3.258065   3.424784  0.000000
# ...      ...      ...     ...         ...          ...        ...       ...
# 6924      47      318     4.0  1496208166     4.429022   4.028317  4.649222
# 6925      47      356     4.5  1496206696     4.164134   4.182701  4.498845
# 6931      47      590     3.5  1496208604     3.835366   3.629115  3.999874
# 6932      47      593     2.0  1496205249     4.161290   2.727577  3.400288
# 6946      47     2028     4.0  1496205180     4.146277   4.146540  4.125148
# 7061      48      653     4.0  1127128598     3.092308   0.000000  3.500022
# 7062      48      780     3.5  1127128851     3.445545   3.510900  3.300139
# 7065      48     1356     4.5  1127128828     3.879121   4.804657  4.666687
# 7071      48     1653     4.5  1127128650     3.953488   4.253264  4.250017
# 7077      48     2571     5.0  1127128841     4.192446   5.000000  4.607196
# 7082      48     3793     3.5  1127128889     3.699248   3.832003  4.000000
# 7083      48     4886     5.0  1127128753     3.871212   0.000000  4.000454
# 7084      48     5349     4.0  1127128913     3.540984   4.144782  4.249127
# 7091      49      110     4.0  1493093005     4.031646   4.000000  4.571604
# 7092      49      318     4.0  1493089778     4.429022   4.098725  4.625051
# 7093      49      356     4.0  1493089782     4.164134   4.000000  4.399965
# 7094      49      527     4.5  1493089770     4.225000   4.506640  4.800018
# 7098      49     2028     4.5  1493089784     4.146277   4.489915  4.928537
# 7099      49     2571     4.5  1493093047     4.192446   4.533408  4.692236
# 7101      49     5218     4.0  1493093122     3.688235   0.000000  3.749935
# 7104      49    70286     4.0  1493093030     3.776923   0.000000  4.124958
# 7106      49    79132     4.5  1493093216     4.066434   4.305374  4.699901
# 7112      50        1     3.0  1514238116     3.920930   3.000000  4.001210
# 7113      50       32     3.0  1523740563     3.983051   3.252955  4.200129
# 7115      50      165     3.0  1514238058     3.555556   3.027926  0.000000
# 7116      50      296     4.0  1500573696     4.197068   3.824539  5.000000
# 7117      50      318     3.5  1514237959     4.429022   4.000000  5.000000
# 7118      50      356     3.0  1514238146     4.164134   3.589727  4.624755
# 7120      50      593     3.5  1514237974     4.161290   3.978425  4.714186
# 7122      50      608     4.0  1514238092     4.116022   4.507434  0.000000
#
# [482 rows x 7 columns]

# %%
predicted = predicted[ (predicted['cosine'] > 0) & (predicted['euclidean'] > 0) ]
def RMSE(X, left_col, right_col):
    return(np.sqrt(np.mean((X[left_col] - X[right_col])**2)))

def MAE(X, left_col, right_col):
    return(np.mean(np.absolute(X[left_col] - X[right_col])) )

for name in ['mean_rating', 'cosine', 'euclidean']:
    print ("MAE of {0} is {1} ".format(name, MAE(predicted, 'rating', name)))

for name in ['mean_rating', 'cosine', 'euclidean']:
    print ("RMSE of {0} is {1} ".format(name, RMSE(predicted, 'rating', name)))
# Out:
# MAE of mean_rating is 0.6732807276979298
# MAE of cosine is 0.5531792589753918
# MAE of euclidean is 0.40421532736958293
# RMSE of mean_rating is 0.8576843201841777
# RMSE of cosine is 0.7377415273102896
# RMSE of euclidean is 0.5665102964641624
